# %%
import bonobo
import datetime
import redis
from google.cloud import bigquery
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file('SWOO-Analytics-BQ-214c24ac27fb.json')
project_id = 'swoo-analytics-bq'
client = bigquery.Client(credentials= credentials,project=project_id)

def App_DAU_WAU_MAU(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date as Date,max(DAU) as DAU,max(WAU) as WAU,max(MAU) as MAU from `daily_dashboard.App_DAU_WAU_MAU` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Bingo_Preferential_Cards(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,show_time,max(players) as Players,max(winners) as winners from `daily_dashboard.Bingo_Preferential_Cards` group by 1,2;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Bingo_Preferential_Cards1(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(players) as Players,max(winners) as winners,show_timing from `daily_dashboard.Bingo_Preferential_Cards1` group by 1,4;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Bingo_Preferential_Cards_New_Users(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(new_players) as new_players,max(new_users_preferential_cards) as new_users_preferential_cards,max(new_user_winners) as new_user_winners from `daily_dashboard.Bingo_Preferential_Cards_New_Users` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Cumulative_Wallet_Balance(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(cum_wallet_balence) as cum_wallet_balence from `daily_dashboard.Cumulative_Wallet_Balance` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Game_Players_By_Shows(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,Time,game_type_id,game_id,max(users) as users from `daily_dashboard.Game_Players_By_Shows` group by 1,2,3,4;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def game_players_by_type(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,game,max(users) as users from `daily_dashboard.game_players_by_type` group by 1,2;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Games_DAU(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,x_games_played,body_name,max(users) as users from `daily_dashboard.Games_DAU` group by 1,2,3;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def games_happened_per_day(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(games) as games from `daily_dashboard.games_happened_per_day` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Games_play_hour(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,hour,body_name,max(users) as users from `daily_dashboard.Games_play_hour` group by 1,2,3;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Lives_Consumed_Per_Day(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select CDate,max(TotalLivesConsumed) as TotalLivesConsumed from `daily_dashboard.Lives_Consumed_Per_Day` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Lives_Generated_Per_Day(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(lives_generated) as lives_generated from `daily_dashboard.Lives_Generated_Per_Day` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Lives_Generated_Per_Source(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(lives_generated) as lives_generated,Source from `daily_dashboard.Lives_Generated_Per_Source` group by 1,3;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def New_Users_Daily_Funnel(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select install_date,max(New_Users) as New_Users,max(Registered_Users) as Registered_Users,max(Game_Players) as Game_Players,max(Referred_Others) as Referred_Others from `daily_dashboard.New_Users_Daily_Funnel` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def New_Users_Winning_Ratio(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(new_users) as new_users,max(users_won) as users_won,max(winning_ratio) as winning_ratio from `daily_dashboard.New_Users_Winning_Ratio` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Referrals(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(referrals_made) as referrals_made,max(users_referred) as users_referred,max(Joined_Through_Referrals) as Joined_Through_Referrals from `daily_dashboard.Referrals` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Ringer_Optins(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(Ringer_Optins) as Ringer_Optins from `daily_dashboard.Ringer_Optins` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def Trivia_PollMania_DAU(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select CDate,CMinute,GameType,max(DistinctUsers) as DistinctUsers from `daily_dashboard.Trivia_PollMania_DAU` group by 1,2,3;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_app_derived_data_v1(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,type,device_channel from `daily_dashboard.ua_app_derived_data_v1` group by 1,2,3;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_retention(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select Date,MAX(D1) AS D1,MAX(D7) AS D7,MAX(D14) AS D14,MAX(D30) AS D30 from `daily_dashboard.ua_retention` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_total_games_played(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(Users) as Users from `daily_dashboard.ua_total_games_played` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_uninstalled(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,max(daily_users_unistalled) as daily_users_unistalled from `daily_dashboard.ua_uninstalled` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_user_first_opened(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select Date,max(DAU) as DAU from `daily_dashboard.ua_user_first_opened` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_user_opened(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select Date,max(DAU) as DAU from `daily_dashboard.ua_user_opened` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_user_played(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select DATE,max(Users) as Users from `daily_dashboard.ua_user_played` group by 1;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_user_session_decile(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,`range`,max(users) as users,max(avg_session_length) as avg_session_length from `daily_dashboard.ua_user_session_decile` group by 1,2;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def ua_user_sessions(dataset_id,table_id,table_ref):
    dataset_id = dataset_id
    job_config = bigquery.QueryJobConfig()
    # Set the destination table
    table_ref = client.dataset(dataset_id).table(table_id)
    job_config.destination = table_ref
    job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
    sql = """
    select date,user_id,max(session_length) as session_length,max(rank) as rank from `daily_dashboard.ua_user_sessions` group by 1,2;
    """
    query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query

    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
    
def runall():
    App_DAU_WAU_MAU('daily_dashboard','App_DAU_WAU_MAU','App_DAU_WAU_MAU')
    Bingo_Preferential_Cards('daily_dashboard','Bingo_Preferential_Cards','Bingo_Preferential_Cards')
    Bingo_Preferential_Cards1('daily_dashboard','Bingo_Preferential_Cards1','Bingo_Preferential_Cards1')
    Bingo_Preferential_Cards_New_Users('daily_dashboard','Bingo_Preferential_Cards_New_Users','Bingo_Preferential_Cards_New_Users')
    Cumulative_Wallet_Balance('daily_dashboard','Cumulative_Wallet_Balance','Cumulative_Wallet_Balance')
    Game_Players_By_Shows('daily_dashboard','Game_Players_By_Shows','Game_Players_By_Shows')
    game_players_by_type('daily_dashboard','game_players_by_type','game_players_by_type')
    Games_DAU('daily_dashboard','Games_DAU','Games_DAU')
    games_happened_per_day('daily_dashboard','games_happened_per_day','games_happened_per_day')
    Games_play_hour('daily_dashboard','Games_play_hour','Games_play_hour')
    Lives_Consumed_Per_Day('daily_dashboard','Lives_Consumed_Per_Day','Lives_Consumed_Per_Day')
    Lives_Generated_Per_Day('daily_dashboard','Lives_Generated_Per_Day','Lives_Generated_Per_Day')
    Lives_Generated_Per_Source('daily_dashboard','Lives_Generated_Per_Source','Lives_Generated_Per_Source')
    New_Users_Daily_Funnel('daily_dashboard','New_Users_Daily_Funnel','New_Users_Daily_Funnel')
    New_Users_Winning_Ratio('daily_dashboard','New_Users_Winning_Ratio','New_Users_Winning_Ratio')
    Referrals('daily_dashboard','Referrals','Referrals')
    Ringer_Optins('daily_dashboard','Ringer_Optins','Ringer_Optins')
    Trivia_PollMania_DAU('daily_dashboard','Trivia_PollMania_DAU','Trivia_PollMania_DAU')
    #ua_app_derived_data_v1('daily_dashboard','ua_app_derived_data_v1','ua_app_derived_data_v1')
    ua_retention('daily_dashboard','ua_retention','ua_retention')
    ua_total_games_played('daily_dashboard','ua_total_games_played','ua_total_games_played')
    ua_uninstalled('daily_dashboard','ua_uninstalled','ua_uninstalled')
    ua_user_first_opened('daily_dashboard','ua_user_first_opened','ua_user_first_opened')
    ua_user_opened('daily_dashboard','ua_user_opened','ua_user_opened')
    ua_user_played('daily_dashboard','ua_user_played','ua_user_played')
    ua_user_session_decile('daily_dashboard','ua_user_session_decile','ua_user_session_decile')
    ua_user_sessions('daily_dashboard','ua_user_sessions','ua_user_sessions')
    
                               
runall()
# Out:
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/App_DAU_WAU_MAU
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/Bingo_Preferential_Cards
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/Bingo_Preferential_Cards1
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/Bingo_Preferential_Cards_New_Users
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/Cumulative_Wallet_Balance
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/Game_Players_By_Shows
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/game_players_by_type
# Query results loaded to table /projects/swoo-analytics-bq/datasets/daily_dashboard/tables/Games_DAU
# ...
